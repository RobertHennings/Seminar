# %% [markdown]
# ### 0. Initial Settings

# %%
import pandas as pd
"..."
# Out:
# '...'

# %% [markdown]
# ### 1. Load data

# %%
# something around pd.read_csv() or pd.DataFrame()### 1. Load data

# %% [markdown]
# Following structure is cloesly related to the final presentation

# %% [markdown]
# ### 2.1. Modern Energy Commodites Markets

# %%
## PPP Puzzle

# %%
## Oil and Gas global production and consumption

# %%
## Financial Markets: Oil and Gas OI over time

# %% [markdown]
# ### 2.2. Research hypothesis

# %%
## Energy price contribution to inflation - EU/US

# %%
## Rolling Vola of Exchange Rates
